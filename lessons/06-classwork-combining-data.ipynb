# %% [markdown]
# # 06 - Combining data with merges

# %%
import pandas as pd
import math

pd.set_option('display.max_columns', 100)

# %% [markdown]
# ## 1. Match candidate districts from the FEC with demographic data from the census

# %% [markdown]
# ### a. Load candidate and demographic files to identify common attributes

# %% [markdown]
# Candidate files exist as bulk data from the [FEC's website](https://www.fec.gov/data/browse-data/?tab=bulk-data)

# %%
candidate_header = pd.read_csv('../answers/downloaded_data/cn_header_file.csv').columns.tolist()
candidates = pd.read_csv('../answers/downloaded_data/cn22.txt', sep='|', names=candidate_header)

# %%
# candidate_header

# %%
candidates.head(2)
# Out:
#      CAND_ID            CAND_NAME CAND_PTY_AFFILIATION  CAND_ELECTION_YR  \
# 0  H0AK00105         LAMB, THOMAS                  NNE              2020
# 1  H0AL01055  CARL, JERRY LEE, JR                  REP              2022
#
#   CAND_OFFICE_ST CAND_OFFICE  CAND_OFFICE_DISTRICT CAND_ICI CAND_STATUS  \
# 0             AK           H                   0.0        C           N
# 1             AL           H                   1.0        I           C
#
#     CAND_PCC                CAND_ST1 CAND_ST2 CAND_CITY CAND_ST  CAND_ZIP
# 0  C00607515  1861 W LAKE LUCILLE DR      NaN   WASILLA      AK   99654.0
# 1  C00697789           PO BOX 852138      NaN    MOBILE      AL   36685.0

# %%
# district level
demographics = pd.read_csv('../answers/downloaded_data/ACSDT5Y2019.B01003_2021-07-14T121439/ACSDT5Y2019.B01003_data_with_overlays_2021-07-14T121436.csv', header=1)

# %%
demographics.head(2)
# Out:
#               id                               Geographic Area Name  \
# 0  5001600US0101  Congressional District 1 (116th Congress), Ala...
# 1  5001600US0102  Congressional District 2 (116th Congress), Ala...
#
#    Estimate!!Total Margin of Error!!Total
# 0         710135.0                    615
# 1         679684.0                   2213

# %%
demographics['Geographic Area Name'][0]
# Out:
# 'Congressional District 1 (116th Congress), Alabama'

# %% [markdown]
# Looking at the first couple of entries, what could be common attributes?
#
# - Geographic area
#     - District number
#     - State

# %%
# demographics['state_name'] = demographics['Geographic Area Name'].str.split(', ')

# %%
demographics['district_id'] = demographics['id'].str[-2:]

# %%
demographics['state_fips'] = demographics['id'].str[-4:-2]

# %%
demographics.head()
# Out:
#               id                               Geographic Area Name  \
# 0  5001600US0101  Congressional District 1 (116th Congress), Ala...
# 1  5001600US0102  Congressional District 2 (116th Congress), Ala...
# 2  5001600US0103  Congressional District 3 (116th Congress), Ala...
# 3  5001600US0104  Congressional District 4 (116th Congress), Ala...
# 4  5001600US0105  Congressional District 5 (116th Congress), Ala...
#
#    Estimate!!Total Margin of Error!!Total  \
# 0         710135.0                    615
# 1         679684.0                   2213
# 2         708888.0                   1544
# 3         684757.0                   1511
# 4         720362.0                    234
#
#                                           state_name district_id state_fips
# 0  [Congressional District 1 (116th Congress), Al...          01         01
# 1  [Congressional District 2 (116th Congress), Al...          02         01
# 2  [Congressional District 3 (116th Congress), Al...          03         01
# 3  [Congressional District 4 (116th Congress), Al...          04         01
# 4  [Congressional District 5 (116th Congress), Al...          05         01

# %% [markdown]
# ### b. Format candidates table

# %%
candidates['district_str'] = candidates['CAND_OFFICE_DISTRICT'].astype(str)

# %%
candidates['district_str'] = candidates['district_str'].apply(lambda x: x.split('.')[0])

# %%
candidates['district_str'] = candidates['district_str'].str.zfill(2)

# %% [markdown]
# ### c. Format demographics table

# %% [markdown]
# How can we identify districts and states the way that the FEC identifies? Split the id column into state ID and district ID
#
# [Read up on splicing notation here](https://www.oreilly.com/content/how-do-i-use-the-slice-notation-in-python/)
#
# [Find FIPs codes here](https://www.nrcs.usda.gov/wps/portal/nrcs/detail/?cid=nrcs143_013696)

# %%
demographics.head()
# Out:
#               id                               Geographic Area Name  \
# 0  5001600US0101  Congressional District 1 (116th Congress), Ala...
# 1  5001600US0102  Congressional District 2 (116th Congress), Ala...
# 2  5001600US0103  Congressional District 3 (116th Congress), Ala...
# 3  5001600US0104  Congressional District 4 (116th Congress), Ala...
# 4  5001600US0105  Congressional District 5 (116th Congress), Ala...
#
#    Estimate!!Total Margin of Error!!Total  \
# 0         710135.0                    615
# 1         679684.0                   2213
# 2         708888.0                   1544
# 3         684757.0                   1511
# 4         720362.0                    234
#
#                                           state_name district_id state_fips
# 0  [Congressional District 1 (116th Congress), Al...          01         01
# 1  [Congressional District 2 (116th Congress), Al...          02         01
# 2  [Congressional District 3 (116th Congress), Al...          03         01
# 3  [Congressional District 4 (116th Congress), Al...          04         01
# 4  [Congressional District 5 (116th Congress), Al...          05         01

# %% [markdown]
# Identify...
#
# - Left table: demographics
# - Right table: state_lookup
# - Left key: state_fips
# - Right key: FIPS
# - Merge type: left

# %%
state_lookup = pd.read_html('https://www.nrcs.usda.gov/wps/portal/nrcs/detail/?cid=nrcs143_013696')
state_lookup = state_lookup[0]
state_lookup = state_lookup.drop(index=[55])
# [({'Name': 'District of Columbia', 'Postal Code': 'DC', 'FIPS': '11'})]

state_lookup['FIPS'] = state_lookup['FIPS'].apply(lambda x: str(x).split('.')[0].zfill(2))

# %%
state_lookup.head(2)
# Out:
#       Name Postal Code FIPS
# 0  Alabama          AL   01
# 1   Alaska          AK   02

# %%
demographics_labeled = demographics.merge(state_lookup[['FIPS', 'Postal Code']], how='left', left_on='state_fips', right_on='FIPS')

# %%
demographics_labeled = demographics_labeled.drop(['state_name', 'FIPS'], axis=1)

# %%
demographics_labeled.head(2)
# Out:
#               id                               Geographic Area Name  \
# 0  5001600US0101  Congressional District 1 (116th Congress), Ala...
# 1  5001600US0102  Congressional District 2 (116th Congress), Ala...
#
#    Estimate!!Total Margin of Error!!Total district_id state_fips Postal Code
# 0         710135.0                    615          01         01          AL
# 1         679684.0                   2213          02         01          AL

# %% [markdown]
# ### d. Merge formatted tables
#
# We need the identifying columns to be in the same format and variable type. We can do a double merge or we can create a new key with district and state abbreviation in each table.
#
# [Read about merging in pandas here](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.merge.html)
#
# Identify...
#
# - Left table: candidates
# - Right table: demographics_labeled
# - Left key: key
# - Right key: key
# - Merge type: left

# %%
candidates['key'] = candidates['district_str'] + candidates['CAND_OFFICE_ST']

# %%
demographics_labeled['key'] = demographics_labeled['district_id'] + demographics_labeled['Postal Code']

# %%
len(demographics_labeled['key']), len(demographics_labeled['key'].unique())
# Out:
# (440, 440)

# %%
candidates_demographics = candidates.merge(demographics_labeled, on='key', how='left')

# %% [markdown]
# ## 2. Clean data

# %%
len(candidates_demographics), len(candidates), len(demographics_labeled)
# Out:
# (5377, 5377, 440)

# %%
candidates_2022 = candidates_demographics[candidates_demographics['CAND_ELECTION_YR'] == 2022]

# %%
# candidates_2022

# %% [markdown]
# ### a. Separate house candidates from senate candidates

# %%
senate_demographics = candidates_2022[candidates_2022['CAND_OFFICE'] == 'S']
house_demographics = candidates_2022[candidates_2022['CAND_OFFICE'] == 'H']

# %% [markdown]
# ### b. Find districts that don't exist

# %%
demographics_labeled[demographics_labeled['Postal Code'] == 'AS']
# Out:
# Empty DataFrame
# Columns: [id, Geographic Area Name, Estimate!!Total, Margin of Error!!Total, district_id, state_fips, Postal Code, key]
# Index: []

# %%
demographics_labeled[demographics_labeled['Postal Code'] == 'OR']
# Out:
#                 id                               Geographic Area Name  \
# 323  5001600US4101  Congressional District 1 (116th Congress), Oregon
# 324  5001600US4102  Congressional District 2 (116th Congress), Oregon
# 325  5001600US4103  Congressional District 3 (116th Congress), Oregon
# 326  5001600US4104  Congressional District 4 (116th Congress), Oregon
# 327  5001600US4105  Congressional District 5 (116th Congress), Oregon
#
#      Estimate!!Total Margin of Error!!Total district_id state_fips  \
# 323         842952.0                   1268          01         41
# 324         817793.0                   1035          02         41
# 325         837545.0                   1804          03         41
# 326         803194.0                   1213          04         41
# 327         828319.0                   1515          05         41
#
#     Postal Code   key
# 323          OR  01OR
# 324          OR  02OR
# 325          OR  03OR
# 326          OR  04OR
# 327          OR  05OR

# %%
house_demographics[house_demographics['id'].isna()].sort_values('CAND_OFFICE_ST')
# Out:
#         CAND_ID                               CAND_NAME CAND_PTY_AFFILIATION  \
# 1547  H2AL12017                       VON KRIEG, BIANCA                  DEM
# 2495  H4AS00036                            AMATA, AUMUA                  REP
# 1585  H2CA00146                    TOOMIM, LEAH MELISSA                  REP
# 246   H0DC00058                  NORTON, ELEANOR HOLMES                  DEM
# 1715  H2DC01011                     HAMILTON, WENDY REV                  DEM
# 1716  H2DC10012                WINDHAUSER, ANGELA MARIE                  REP
# 2734  H6FL08213                      GRAYSON, ALAN MARK                  DEM
# 3123  H8GU01020           SAN NICOLAS, MICHAEL F.Q. MR.                  DEM
# 1902  H2IN90019                        PATEL, HIREN MR.                  REP
# 1904  H2KS21010                GARRETT, FRANK DUNCAN MR                  REP
# 1985  H2MI43011                    CLARK, WYATT BRONSON                  DEM
# 3263  H8MP00041    SABLAN, GREGORIO KILILI CAMACHO REP.                  IND
# 2075  H2NH00025                BURNS, ROBERT ANDREW MR.                  REP
# 2114  H2NV00068                    CENTENO, JAIME MR JR                  REP
# 2127  H2NY00069                     JOSEPH, VLADIMY MR.                  DEM
# 2239  H2OR06017                          SMITH, LORETTA                  DEM
# 2240  H2PA00034                 BURTON, DANIEL LEROY JR                  REP
# 2305  H2TX00148                    CATHEY, CAITLIN CREE                  DEM
# 2429  H2TX37017                   MARTINEZ, ANGEL DAVID                  DEM
# 2430  H2TX37025                  SASINOWSKI, JAMES SASS                  OTH
# 1261  H0TX07170                            HUNT, WESLEY                  REP
# 2458  H2VI00082                        PLASKETT, STACEY                  DEM
# 2479  H2WA22019  SCOTT(D), CHARLIE (CHARLES) LEE SEN SR                  DEM
# 2485  H2WV04023                            TOAD, BOMA W                  FRE
#
#       CAND_ELECTION_YR CAND_OFFICE_ST CAND_OFFICE  CAND_OFFICE_DISTRICT  \
# 1547              2022             AL           H                  12.0
# 2495              2022             AS           H                   0.0
# 1585              2022             CA           H                   0.0
# 246               2022             DC           H                   0.0
# 1715              2022             DC           H                   0.0
# 1716              2022             DC           H                   0.0
# 2734              2022             FL           H                  28.0
# 3123              2022             GU           H                   0.0
# 1902              2022             IN           H                  90.0
# 1904              2022             KS           H                  21.0
# 1985              2022             MI           H                  43.0
# 3263              2022             MP           H                   0.0
# 2075              2022             NH           H                   0.0
# 2114              2022             NV           H                   0.0
# 2127              2022             NY           H                   0.0
# 2239              2022             OR           H                   6.0
# 2240              2022             PA           H                   0.0
# 2305              2022             TX           H                   0.0
# 2429              2022             TX           H                  37.0
# 2430              2022             TX           H                   0.0
# 1261              2022             TX           H                  37.0
# 2458              2022             VI           H                   0.0
# 2479              2022             WA           H                  22.0
# 2485              2022             WV           H                   4.0
#
#      CAND_ICI CAND_STATUS   CAND_PCC                    CAND_ST1  \
# 1547        C           N  C00777615              530 DIVISADERO
# 2495        I           N  C00393041                 PO BOX 6171
# 1585        C           N  C00776948   1112 MONTANA AVENUE #3-88
# 246         I           C  C00244335         10 NINTH STREET, SE
# 1715        C           C  C00763896            85 DANBURY ST SW
# 1716      NaN           N        NaN               PO BOX 785098
# 2734        C           N  C00424713            4415 GWYNDALE CT
# 3123        I           C  C00668335   198 W. SANTA BARBARA AVE.
# 1902        C           N  C00762542     4236 SOUTHPORT TRACE DR
# 1904        C           N        NaN         11216 BURTON STREET
# 1985        C           N        NaN         5863 WILLOW PARK RD
# 3263        I           N  C00469882             P.O. BOX 502924
# 2075        C           N  C00779918         91 HITCHING POST LN
# 2114        C           N        NaN      5120 W CHARLESTON BLVD
# 2127        C           N        NaN             1693 NELSON AVE
# 2239      NaN           N  C00783373                PO BOX 42307
# 2240        C           N  C00776286             2 CRANBERRY CIR
# 2305        C           N        NaN           2306 WILDBRIAR DR
# 2429        C           N  C00737999           5309 111TH STREET
# 2430        C           C  C00762336             1105 CLAYTON LN
# 1261      NaN           N  C00701003     1707 1/2 POST OAK BLVD.
# 2458        I           C  C00528182                 PO BOX 1006
# 2479        C           N        NaN  C/O 3584 NANSEMOND PARKWAY
# 2485        C           N  C00762948         822 PRINCETON DRIVE
#
#                               CAND_ST2      CAND_CITY CAND_ST     CAND_ZIP  \
# 1547                        SUITE #458  SAN FRANCISCO      CA      94117.0
# 2495                               NaN      PAGO PAGO      AS      96799.0
# 1585                               NaN   SANTA MONICA      CA      90403.0
# 246                                NaN     WASHINGTON      DC      20003.0
# 1715                               NaN     WASHINGTON      DC      20032.0
# 1716                               NaN  WINTER GARDEN      FL      34778.0
# 2734                               NaN        ORLANDO      FL  328375509.0
# 3123                               NaN         DEDEDO      GU      96929.0
# 1902                               NaN   INDIANAPOLIS      IN      46237.0
# 1904                               NaN   INDEPENDENCE      MO      64054.0
# 1985                           APT 104      CLARKSTON      MI      48346.0
# 3263                               NaN         SAIPAN      MP      96950.0
# 2075                               NaN        BEDFORD      NH       3110.0
# 2114                               NaN      LAS VEGAS      NV      89146.0
# 2127                               NaN          BRONX      NY      10453.0
# 2239                               NaN       PORTLAND      OR      97242.0
# 2240                               NaN         DENVER      PA      17517.0
# 2305                               NaN      ARLINGTON      TX      76014.0
# 2429                               NaN        LUBBOCK      TX      79424.0
# 2430                           APT 208         AUSTIN      TX      78723.0
# 1261                              #525        HOUSTON      TX      77056.0
# 2458                               NaN   FREDERIKSTED      VI        841.0
# 2479  ATTN: SENATOR, SEATTLE, WA 98101        SUFFOLK      VA      23435.0
# 2485                               NaN      HILLSBORO      WV      24946.0
#
#      district_str   key   id Geographic Area Name  Estimate!!Total  \
# 1547           12  12AL  NaN                  NaN              NaN
# 2495           00  00AS  NaN                  NaN              NaN
# 1585           00  00CA  NaN                  NaN              NaN
# 246            00  00DC  NaN                  NaN              NaN
# 1715           00  00DC  NaN                  NaN              NaN
# 1716           00  00DC  NaN                  NaN              NaN
# 2734           28  28FL  NaN                  NaN              NaN
# 3123           00  00GU  NaN                  NaN              NaN
# 1902           90  90IN  NaN                  NaN              NaN
# 1904           21  21KS  NaN                  NaN              NaN
# 1985           43  43MI  NaN                  NaN              NaN
# 3263           00  00MP  NaN                  NaN              NaN
# 2075           00  00NH  NaN                  NaN              NaN
# 2114           00  00NV  NaN                  NaN              NaN
# 2127           00  00NY  NaN                  NaN              NaN
# 2239           06  06OR  NaN                  NaN              NaN
# 2240           00  00PA  NaN                  NaN              NaN
# 2305           00  00TX  NaN                  NaN              NaN
# 2429           37  37TX  NaN                  NaN              NaN
# 2430           00  00TX  NaN                  NaN              NaN
# 1261           37  37TX  NaN                  NaN              NaN
# 2458           00  00VI  NaN                  NaN              NaN
# 2479           22  22WA  NaN                  NaN              NaN
# 2485           04  04WV  NaN                  NaN              NaN
#
#      Margin of Error!!Total district_id state_fips Postal Code
# 1547                    NaN         NaN        NaN         NaN
# 2495                    NaN         NaN        NaN         NaN
# 1585                    NaN         NaN        NaN         NaN
# 246                     NaN         NaN        NaN         NaN
# 1715                    NaN         NaN        NaN         NaN
# 1716                    NaN         NaN        NaN         NaN
# 2734                    NaN         NaN        NaN         NaN
# 3123                    NaN         NaN        NaN         NaN
# 1902                    NaN         NaN        NaN         NaN
# 1904                    NaN         NaN        NaN         NaN
# 1985                    NaN         NaN        NaN         NaN
# 3263                    NaN         NaN        NaN         NaN
# 2075                    NaN         NaN        NaN         NaN
# 2114                    NaN         NaN        NaN         NaN
# 2127                    NaN         NaN        NaN         NaN
# 2239                    NaN         NaN        NaN         NaN
# 2240                    NaN         NaN        NaN         NaN
# 2305                    NaN         NaN        NaN         NaN
# 2429                    NaN         NaN        NaN         NaN
# 2430                    NaN         NaN        NaN         NaN
# 1261                    NaN         NaN        NaN         NaN
# 2458                    NaN         NaN        NaN         NaN
# 2479                    NaN         NaN        NaN         NaN
# 2485                    NaN         NaN        NaN         NaN

# %% [markdown]
# To-do:
# - Add DC to the FIPs table
#
# Districts that don't exist:
#
# - Oregon 6th district
# - NH ("at large")
# - IN 90th district

# %% [markdown]
# ### c. Extract strings

# %% [markdown]
# [Find in pandas](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.find.html?highlight=find#pandas.Series.str.find)

# %%
house_demographics[house_demographics['CAND_NAME'].str.find('NORTON') > -1]
# Out:
#        CAND_ID               CAND_NAME CAND_PTY_AFFILIATION  CAND_ELECTION_YR  \
# 246  H0DC00058  NORTON, ELEANOR HOLMES                  DEM              2022
# 673  H0MI03266     NORTON, THOMAS JOHN                  REP              2022
#
#     CAND_OFFICE_ST CAND_OFFICE  CAND_OFFICE_DISTRICT CAND_ICI CAND_STATUS  \
# 246             DC           H                   0.0        I           C
# 673             MI           H                   3.0        C           C
#
#       CAND_PCC             CAND_ST1 CAND_ST2   CAND_CITY CAND_ST  CAND_ZIP  \
# 246  C00244335  10 NINTH STREET, SE      NaN  WASHINGTON      DC   20003.0
# 673  C00704270     4208 PETTIS AVE.      NaN         ADA      MI   48301.0
#
#     district_str   key             id  \
# 246           00  00DC            NaN
# 673           03  03MI  5001600US2603
#
#                                   Geographic Area Name  Estimate!!Total  \
# 246                                                NaN              NaN
# 673  Congressional District 3 (116th Congress), Mic...         742923.0
#
#     Margin of Error!!Total district_id state_fips Postal Code
# 246                    NaN         NaN        NaN         NaN
# 673                    121          03         26          MI
