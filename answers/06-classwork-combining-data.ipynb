# %% [markdown]
# # 06 - Combining data with merges

# %%
import pandas as pd
import math

pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)

# %% [markdown]
# ## 1. Match candidate districts from the FEC with demographic data from the census

# %% [markdown]
# ### a. Load candidate and demographic files to identify common attributes

# %%
candidate_header = pd.read_csv('downloaded_data/cn_header_file.csv').columns.tolist()
candidates = pd.read_csv('downloaded_data/cn22.txt', sep='|', names=candidate_header)

# %%
candidates.head(2)
# Out:
#      CAND_ID            CAND_NAME CAND_PTY_AFFILIATION  CAND_ELECTION_YR  \
# 0  H0AK00105         LAMB, THOMAS                  NNE              2020
# 1  H0AL01055  CARL, JERRY LEE, JR                  REP              2022
#
#   CAND_OFFICE_ST CAND_OFFICE  CAND_OFFICE_DISTRICT CAND_ICI CAND_STATUS  \
# 0             AK           H                   0.0        C           N
# 1             AL           H                   1.0        I           C
#
#     CAND_PCC                CAND_ST1 CAND_ST2 CAND_CITY CAND_ST  CAND_ZIP
# 0  C00607515  1861 W LAKE LUCILLE DR      NaN   WASILLA      AK   99654.0
# 1  C00697789           PO BOX 852138      NaN    MOBILE      AL   36685.0

# %%
districts = pd.read_csv('downloaded_data/ACSDT5Y2019.B01003_2021-07-14T121439/ACSDT5Y2019.B01003_data_with_overlays_2021-07-14T121436.csv', header=1)

# %% [markdown]
# In order to join candidates and census data, we need the identifying columns to be in the same format and variable type. We can do a double merge or we can create a new key with district and state abbreviation in each table

# %% [markdown]
# ### b. Format candidates table

# %%
candidates['district_str'] = candidates['CAND_OFFICE_DISTRICT'].apply(lambda x: x if math.isnan(x) else str(round(x)).zfill(2))

# %% [markdown]
# ### c. Format demographics table

# %% [markdown]
# How can we identify districts and states the way that the FEC identifies? Split the id column into state ID and district ID
#
# [Read up on splicing notation here](https://www.oreilly.com/content/how-do-i-use-the-slice-notation-in-python/)
#
# [Find FIPs codes here](https://www.nrcs.usda.gov/wps/portal/nrcs/detail/?cid=nrcs143_013696)

# %%
districts['district_id'] = districts['id'].str[-2:]

# %%
districts['state_fips'] = districts['id'].str[-4:-2]

# %% [markdown]
# Now we need the state abbreviation instead of the fips code. We need to look up that value

# %%
state_lookup = pd.read_html('https://www.nrcs.usda.gov/wps/portal/nrcs/detail/?cid=nrcs143_013696')
state_lookup = state_lookup[0]
state_lookup = state_lookup.drop(index=[55])

# FIPS codes need to be have a length of 2 and exist in strings
state_lookup['FIPS'] = state_lookup['FIPS'].apply(lambda x: str(round(x)).zfill(2))

# %%
state_lookup
# Out:
#                         Name Postal Code FIPS
# 0                    Alabama          AL   01
# 1                     Alaska          AK   02
# 2                    Arizona          AZ   04
# 3                   Arkansas          AR   05
# 4                 California          CA   06
# 5                   Colorado          CO   08
# 6                Connecticut          CT   09
# 7                   Delaware          DE   10
# 8                    Florida          FL   12
# 9                    Georgia          GA   13
# 10                    Hawaii          HI   15
# 11                     Idaho          ID   16
# 12                  Illinois          IL   17
# 13                   Indiana          IN   18
# 14                      Iowa          IA   19
# 15                    Kansas          KS   20
# 16                  Kentucky          KY   21
# 17                 Louisiana          LA   22
# 18                     Maine          ME   23
# 19                  Maryland          MD   24
# 20             Massachusetts          MA   25
# 21                  Michigan          MI   26
# 22                 Minnesota          MN   27
# 23               Mississippi          MS   28
# 24                  Missouri          MO   29
# 25                   Montana          MT   30
# 26                  Nebraska          NE   31
# 27                    Nevada          NV   32
# 28             New Hampshire          NH   33
# 29                New Jersey          NJ   34
# 30                New Mexico          NM   35
# 31                  New York          NY   36
# 32            North Carolina          NC   37
# 33              North Dakota          ND   38
# 34                      Ohio          OH   39
# 35                  Oklahoma          OK   40
# 36                    Oregon          OR   41
# 37              Pennsylvania          PA   42
# 38              Rhode Island          RI   44
# 39            South Carolina          SC   45
# 40              South Dakota          SD   46
# 41                 Tennessee          TN   47
# 42                     Texas          TX   48
# 43                      Utah          UT   49
# 44                   Vermont          VT   50
# 45                  Virginia          VA   51
# 46                Washington          WA   53
# 47             West Virginia          WV   54
# 48                 Wisconsin          WI   55
# 49                   Wyoming          WY   56
# 50            American Samoa          AS   60
# 51                      Guam          GU   66
# 52  Northern Mariana Islands          MP   69
# 53               Puerto Rico          PR   72
# 54            Virgin Islands          VI   78

# %%
districts = districts.merge(state_lookup, left_on='state_fips', right_on='FIPS', how='left')

# %%
districts.head(2)
# Out:
#               id                               Geographic Area Name  \
# 0  5001600US0101  Congressional District 1 (116th Congress), Ala...
# 1  5001600US0102  Congressional District 2 (116th Congress), Ala...
#
#    Estimate!!Total Margin of Error!!Total district_id state_fips     Name  \
# 0         710135.0                    615          01         01  Alabama
# 1         679684.0                   2213          02         01  Alabama
#
#   Postal Code FIPS
# 0          AL   01
# 1          AL   01

# %% [markdown]
# Create a common key between the two tables now that columns are formatted

# %%
districts['key'] = districts['district_id'] + districts['Postal Code']

# %%
candidates['key'] = candidates['district_str'] + candidates['CAND_OFFICE_ST']

# %% [markdown]
# ### d. Merge formatted tables
#
# We need the identifying columns to be in the same format and variable type. We can do a double merge or we can create a new key with district and state abbreviation in each table.
#
# [Read about merging in pandas here](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.merge.html)
#
# Identify...
#
# - Left table:
# - Right table:
# - Left key:
# - Right key:
# - Merge type:

# %%
candidates_districts = candidates.merge(districts, on='key', how='left')

# %%
len(candidates_districts), len(districts), len(candidates)
# Out:
# (5377, 440, 5377)

# %%
candidates_districts
# Out:
#         CAND_ID                     CAND_NAME CAND_PTY_AFFILIATION  \
# 0     H0AK00105                  LAMB, THOMAS                  NNE
# 1     H0AL01055           CARL, JERRY LEE, JR                  REP
# 2     H0AL01063  LAMBERT, DOUGLAS WESTLEY III                  REP
# 3     H0AL01097               AVERHART, JAMES                  DEM
# 4     H0AL02087                  ROBY, MARTHA                  REP
# ...         ...                           ...                  ...
# 5372  S8WI00224                  VUKMIR, LEAH                  REP
# 5373  S8WV00119        SWEARENGIN, PAULA JEAN                  DEM
# 5374  S8WV00127               JENKINS, EVAN H                  REP
# 5375  S8WV00135         COPLEY, JIMMY DALE II                  REP
# 5376  S8WV00143          MORRISEY, PATRICK MR                  REP
#
#       CAND_ELECTION_YR CAND_OFFICE_ST CAND_OFFICE  CAND_OFFICE_DISTRICT  \
# 0                 2020             AK           H                   0.0
# 1                 2022             AL           H                   1.0
# 2                 2020             AL           H                   1.0
# 3                 2020             AL           H                   1.0
# 4                 2020             AL           H                   2.0
# ...                ...            ...         ...                   ...
# 5372              2018             WI           S                   0.0
# 5373              2018             WV           S                   0.0
# 5374              2018             WV           S                   0.0
# 5375              2018             WV           S                   0.0
# 5376              2018             WV           S                   0.0
#
#      CAND_ICI CAND_STATUS   CAND_PCC                CAND_ST1 CAND_ST2  \
# 0           C           N  C00607515  1861 W LAKE LUCILLE DR      NaN
# 1           I           C  C00697789           PO BOX 852138      NaN
# 2           O           P  C00701557    7194 STILLWATER BLVD      NaN
# 3           O           P  C00708867  430 SAINT LOUIS STREET      NaN
# 4           I           P  C00462143                     NaN      NaN
# ...       ...         ...        ...                     ...      ...
# 5372        C           P  C00655522             945 POST RD      NaN
# 5373        C           P  C00708891       127 SAPPHIRE LANE      NaN
# 5374        C           P  C00548271            121 OAK LANE      NaN
# 5375        C           N  C00650564     92 BOY SCOUT HOLLOW      NaN
# 5376        C           P  C00651075             PO BOX 1005      NaN
#
#          CAND_CITY CAND_ST  CAND_ZIP district_str   key             id  \
# 0          WASILLA      AK   99654.0           00  00AK  5001600US0200
# 1           MOBILE      AL   36685.0           01  01AL  5001600US0101
# 2     SPANISH FORT      AL   36527.0           01  01AL  5001600US0101
# 3           MOBILE      AL   36602.0           01  01AL  5001600US0101
# 4       MONTGOMERY     NaN       NaN           02  02AL  5001600US0102
# ...            ...     ...       ...          ...   ...            ...
# 5372    BROOKFIELD      WI   53005.0           00  00WI            NaN
# 5373     COAL CITY      WV   25823.0           00  00WV            NaN
# 5374    HUNTINGTON      WV   25701.0           00  00WV            NaN
# 5375     DELBARTON      WV   25670.0           00  00WV            NaN
# 5376   CHARLESTOWN      WV   25414.0           00  00WV            NaN
#
#                                    Geographic Area Name  Estimate!!Total  \
# 0     Congressional District (at Large) (116th Congr...         737068.0
# 1     Congressional District 1 (116th Congress), Ala...         710135.0
# 2     Congressional District 1 (116th Congress), Ala...         710135.0
# 3     Congressional District 1 (116th Congress), Ala...         710135.0
# 4     Congressional District 2 (116th Congress), Ala...         679684.0
# ...                                                 ...              ...
# 5372                                                NaN              NaN
# 5373                                                NaN              NaN
# 5374                                                NaN              NaN
# 5375                                                NaN              NaN
# 5376                                                NaN              NaN
#
#      Margin of Error!!Total district_id state_fips     Name Postal Code FIPS
# 0                     *****          00         02   Alaska          AK   02
# 1                       615          01         01  Alabama          AL   01
# 2                       615          01         01  Alabama          AL   01
# 3                       615          01         01  Alabama          AL   01
# 4                      2213          02         01  Alabama          AL   01
# ...                     ...         ...        ...      ...         ...  ...
# 5372                    NaN         NaN        NaN      NaN         NaN  NaN
# 5373                    NaN         NaN        NaN      NaN         NaN  NaN
# 5374                    NaN         NaN        NaN      NaN         NaN  NaN
# 5375                    NaN         NaN        NaN      NaN         NaN  NaN
# 5376                    NaN         NaN        NaN      NaN         NaN  NaN
#
# [5377 rows x 26 columns]

# %% [markdown]
# ## 2. Clean data
# We would want Senate candidates to be matched with the state as a whole or else there will be no identifier in the Census table or they would be erroneously matched to states with "at large" districts.

# %%
# filter by house candidates only
candidates_house = candidates[candidates['CAND_OFFICE'] == 'H']

# %%
# merge again
house_candidates_districts = candidates_house.merge(districts, on='key', how='left')

# %%
len(house_candidates_districts)
# Out:
# 3578

# %% [markdown]
# How can we check everything is matched as we would expect? There should be 440 different districts. How can we find invalid districts?

# %%
district_counts = pd.DataFrame(house_candidates_districts.groupby('key')['key'].count())
district_counts.columns = ['district_counts']
district_counts = district_counts.reset_index()

# %%
district_counts.sort_values(by='district_counts').head(20)
# Out:
#       key  district_counts
# 467  90IN                1
# 232  06OR                1
# 388  19PA                1
# 453  43MI                1
# 181  04WV                1
# 43   01MP                1
# 216  06CT                1
# 426  28FL                1
# 466  80MI                1
# 14   00PA                1
# 418  26MI                1
# 12   00NV                1
# 327  12AL                1
# 189  05IA                1
# 2    00CA                1
# 465  69HI                1
# 396  21KS                1
# 11   00NH                1
# 6    00IN                1
# 403  22WA                1
